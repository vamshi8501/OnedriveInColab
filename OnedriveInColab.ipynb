# %%
# !wget https://rclone.org/install.sh -O install.sh && sudo bash install.sh
# Out:
# --2024-07-29 10:04:22--  https://rclone.org/install.sh
# Resolving rclone.org (rclone.org)... 95.217.6.16, 2a01:4f9:c012:7154::1
# Connecting to rclone.org (rclone.org)|95.217.6.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4734 (4.6K) [application/x-shellscript]
# Saving to: ‘install.sh’
#
# install.sh          100%[===================>]   4.62K  --.-KB/s    in 0s
#
# 2024-07-29 10:04:22 (55.2 MB/s) - ‘install.sh’ saved [4734/4734]
#
# Archive:  rclone-current-linux-amd64.zip
#    creating: tmp_unzip_dir_for_rclone/rclone-v1.67.0-linux-amd64/
#   inflating: tmp_unzip_dir_for_rclone/rclone-v1.67.0-linux-amd64/rclone  [binary]
#   inflating: tmp_unzip_dir_for_rclone/rclone-v1.67.0-linux-amd64/README.html  [text]
#   inflating: tmp_unzip_dir_for_rclone/rclone-v1.67.0-linux-amd64/git-log.txt  [text]
#   inflating: tmp_unzip_dir_for_rclone/rclone-v1.67.0-linux-amd64/README.txt  [text]
# ...

# %%
# !apt-get install fuse3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fuse3 is already the newest version (3.10.5-1build1).
# The following package was automatically installed and is no longer required:
#   libfuse2
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !rclone config
#n
#onedrive
#33
#
#
#1
#n
#n
#config_token
#1
#1
#y
#y
#q
# Out:
# 2024/07/29 10:04:43 NOTICE: Config file "/root/.config/rclone/rclone.conf" not found - using defaults
# No remotes found, make a new one?
# n) New remote
# s) Set configuration password
# q) Quit config
# n/s/q> n
#
# Enter name for new remote.
# name> onedrive
#
# Option Storage.
# Type of storage to configure.
# Choose a number from below, or type in your own value.
#  1 / 1Fichier
#    \ (fichier)
#  2 / Akamai NetStorage
#    \ (netstorage)
#  3 / Alias for an existing remote
#    \ (alias)
#  4 / Amazon S3 Compliant Storage Providers including AWS, Alibaba, ArvanCloud, Ceph, ChinaMobile, Cloudflare, DigitalOcean, Dreamhost, GCS, HuaweiOBS, IBMCOS, IDrive, IONOS, LyveCloud, Leviia, Liara, Linode, Magalu, Minio, Netease, Petabox, RackCorp, Rclone, Scaleway, SeaweedFS, StackPath, Storj, Synology, TencentCOS, Wasabi, Qiniu and others
#    \ (s3)
#  5 / Backblaze B2
#    \ (b2)
#  6 / Better checksums for other remotes
#    \ (hasher)
#  7 / Box
#    \ (box)
#  8 / Cache a remote
# ...

# %%
# !sudo mkdir /content/onedrive/
# !nohup rclone --vfs-cache-mode writes mount onedrive: /content/onedrive/ &
# Out:
# mkdir: cannot create directory ‘/content/onedrive/’: File exists
# nohup: appending output to 'nohup.out'

# %%
import os
os.listdir('/content/onedrive')
# Out:
# ['.ipynb_checkpoints',
#  '08_Olympic_T_F_Highlights_med_res_h264',
#  '112830_Beijing_Summit_Rev4_SM',
#  'ADPL_India Employee Handbook(Policies Guide)_2023.docx',
#  'Airflow.pptx',
#  'Amnet Digital_Annual Performance Appraisal 2023_TSE,JSE,SE,SSE (1).xlsx',
#  'Amnet Digital_Annual Performance Appraisal 2023_TSE,JSE,SE,SSE.xlsx',
#  'Apps',
#  'Attachments',
#  'BO_LIFECYCLE_15',
#  'Bank account details.xlsx',
#  'Book 1.xlsx',
#  'Book 2.xlsx',
#  'Book 3.xlsx',
#  'Book.xlsx',
#  'Colab Notebooks',
#  'Customer_Segmentation',
#  'Desktop',
#  'DocTR_Text_Extractor.ipynb',
#  'Document 1.docx',
#  'Document.docx',
#  'Document1.docx',
#  'Documents',
#  'Kubernetes.docx',
#  'Kubernetes.pptx',
#  'MAM bg&product.xlsx',
#  'MLOPS',
#  'MLflow Documentation.docx',
#  'MM06289_Dixon_2',
#  'Meet Recordings',
#  'Microsoft Teams Chat Files',
#  'NIKE_PARALLEL_JOURNEYS_Cricket_India',
#  'NKVR3173H_NikeBetterWorld_REVISED_HDbackgorund',
# ...

# %%
# !fusermount -u /content/onedrive
